# %% [markdown]
# #  Exploratory Data Analysis

# %% [markdown]
# ## Problem statement

# %%
# importing all necessary packages
library(tidyverse) # import our dataset
library(ggplot2) # to plot the graph 
library(GGally) # to plot the pairplot
library(psych) # to plot the correlation plot
library(ggpubr)
library(reshape)
library(datasets)
# Out:
# ── Attaching packages ────────────────────────────────── tidyverse 1.3.2 ──
# ✔ ggplot2 3.3.6      ✔ purrr   0.3.4
# ✔ tibble  3.1.7      ✔ dplyr   1.0.10
# ✔ tidyr   1.2.1      ✔ stringr 1.4.0
# ✔ readr   2.1.3      ✔ forcats 0.5.2
# ── Conflicts ───────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# Registered S3 method overwritten by 'GGally':
#   method from
#   +.gg   ggplot2
#
#
# Attaching package: ‘psych’
#
#
# The following objects are masked from ‘package:ggplot2’:
#
#     %+%, alpha
#
#
#
# Attaching package: ‘reshape’
#
#
# The following object is masked from ‘package:dplyr’:
#
#     rename
#
#
# The following objects are masked from ‘package:tidyr’:
#
#     expand, smiths

# %% [markdown]
# ## Load data

# %%
df <- read.csv('diabetes.csv') # load our dataset into the working environment

# %%
head(df)# to see the first five rows of our data
# Out:
#   Pregnancies Glucose BloodPressure SkinThickness Insulin BMI
# 1 6           148     72            35              0     33.6
# 2 1            85     66            29              0     26.6
# 3 8           183     64             0              0     23.3
# 4 1            89     66            23             94     28.1
# 5 0           137     40            35            168     43.1
# 6 5           116     74             0              0     25.6
#   DiabetesPedigreeFunction Age Outcome
# 1 0.627                    50  1
# 2 0.351                    31  0
# 3 0.672                    32  1
# 4 0.167                    21  0
# 5 2.288                    33  1
# 6 0.201                    30  0

# %%
tail(df) # to see the last five rows of our dataset
# Out:
#     Pregnancies Glucose BloodPressure SkinThickness Insulin BMI
# 763  9           89     62             0              0     22.5
# 764 10          101     76            48            180     32.9
# 765  2          122     70            27              0     36.8
# 766  5          121     72            23            112     26.2
# 767  1          126     60             0              0     30.1
# 768  1           93     70            31              0     30.4
#     DiabetesPedigreeFunction Age Outcome
# 763 0.142                    33  0
# 764 0.171                    63  0
# 765 0.340                    27  0
# 766 0.245                    30  0
# 767 0.349                    47  1
# 768 0.315                    23  0

# %%
sum(is.na(df)) # to check if there is any null values in our dataset
# Out:
# [1] 0

# %%
dim(df) # the dimension of our dataset and have 768 rows and 9 columns
# Out:
# [1] 768   9

# %%
sapply(df, class) # to see the type of our dataframe
# Out:
#              Pregnancies                  Glucose            BloodPressure
#                "integer"                "integer"                "integer"
#            SkinThickness                  Insulin                      BMI
#                "integer"                "integer"                "numeric"
# DiabetesPedigreeFunction                      Age                  Outcome
#                "numeric"                "integer"                "integer"

# %%
summary(df) # to calculate the summary of our dataset
# Out:
#   Pregnancies        Glucose      BloodPressure    SkinThickness
#  Min.   : 0.000   Min.   :  0.0   Min.   :  0.00   Min.   : 0.00
#  1st Qu.: 1.000   1st Qu.: 99.0   1st Qu.: 62.00   1st Qu.: 0.00
#  Median : 3.000   Median :117.0   Median : 72.00   Median :23.00
#  Mean   : 3.845   Mean   :120.9   Mean   : 69.11   Mean   :20.54
#  3rd Qu.: 6.000   3rd Qu.:140.2   3rd Qu.: 80.00   3rd Qu.:32.00
#  Max.   :17.000   Max.   :199.0   Max.   :122.00   Max.   :99.00
#     Insulin           BMI        DiabetesPedigreeFunction      Age
#  Min.   :  0.0   Min.   : 0.00   Min.   :0.0780           Min.   :21.00
#  1st Qu.:  0.0   1st Qu.:27.30   1st Qu.:0.2437           1st Qu.:24.00
#  Median : 30.5   Median :32.00   Median :0.3725           Median :29.00
#  Mean   : 79.8   Mean   :31.99   Mean   :0.4719           Mean   :33.24
#  3rd Qu.:127.2   3rd Qu.:36.60   3rd Qu.:0.6262           3rd Qu.:41.00
#  Max.   :846.0   Max.   :67.10   Max.   :2.4200           Max.   :81.00
#     Outcome
#  Min.   :0.000
#  1st Qu.:0.000
#  Median :0.000
#  Mean   :0.349
#  3rd Qu.:1.000
#  Max.   :1.000

# %%
a <- ggplot(data = df, aes(x = Pregnancies)) +
    geom_histogram( color = "red", fill = "blue", alpha = 0.1) + geom_density()
b <- ggplot(data = df, aes(x = Glucose)) +
    geom_histogram( color = "red", fill = "blue", alpha = 0.1) + geom_density()
c <- ggplot(data = df, aes(x = BloodPressure)) +
    geom_histogram( color = "red", fill = "blue", alpha = 0.1) + geom_density()
d <- ggplot(data = df, aes(x = SkinThickness)) +
    geom_histogram( color = "red", fill = "blue", alpha = 0.1) + geom_density()
e <- ggplot(data = df, aes(x = Insulin)) +
    geom_histogram( color = "red", fill = "blue", alpha = 0.1) +geom_density()
f <- ggplot(data = df, aes(x = BMI)) +
    geom_histogram( color = "red", fill = "blue", alpha = 0.1) + geom_density()
g <- ggplot(data = df, aes(x = DiabetesPedigreeFunction)) +
    geom_histogram( color = "red", fill = "blue", alpha = 0.1) +geom_density()
h <- ggplot(data = df, aes(x = Age)) +
    geom_histogram( color = "red", fill = "blue", alpha = 0.1) +geom_density()
ggarrange(a, b, c, d,e,f,g, h + rremove("x.text"), 
          labels = c("a", "b", "c", "d","e", "f", "g", "h"),
          ncol = 2, nrow = 2)
# Out:
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
#
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
#
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
#
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
#
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
#
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
#
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
#
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# $`1`
#
# $`2`
#
# attr(,"class")
# [1] "list"      "ggarrange"
# plot without title
# plot without title

# %%
ggplot(data = df, aes(x =Outcome, fill = Outcome)) +
    geom_bar()
# Out:
# plot without title

# %%
# plotting the correlation plot by using the psych package
corPlot(df[, 1:8])
# Out:
# Plot with title “Correlation plot”

# %% [markdown]
# ## Split the Data to train-test split

# %%
library(caret)
# Out:
# Loading required package: lattice
#
#
# Attaching package: ‘caret’
#
#
# The following object is masked from ‘package:purrr’:
#
#     lift

# %%
df$Outcome<- factor(df$Outcome, 
                  levels = c(0, 1), 
                  labels = c("Positive", "Negative"))

# %%
# create train-test split of the data so as to use in validation of our model

limits <- createDataPartition(df$Outcome, p=0.90, list=FALSE)
# select 20% of the data for validation
testdf <- df[-limits,]
# use the remaining 80% of data to training and testing the models
traindf <- df[limits,]

# %%
str(traindf)
# Out:
# 'data.frame':	692 obs. of  9 variables:
#  $ Pregnancies             : int  6 1 8 1 0 5 3 10 2 8 ...
#  $ Glucose                 : int  148 85 183 89 137 116 78 115 197 125 ...
#  $ BloodPressure           : int  72 66 64 66 40 74 50 0 70 96 ...
#  $ SkinThickness           : int  35 29 0 23 35 0 32 0 45 0 ...
#  $ Insulin                 : int  0 0 0 94 168 0 88 0 543 0 ...
#  $ BMI                     : num  33.6 26.6 23.3 28.1 43.1 25.6 31 35.3 30.5 0 ...
#  $ DiabetesPedigreeFunction: num  0.627 0.351 0.672 0.167 2.288 ...
#  $ Age                     : int  50 31 32 21 33 30 26 29 53 54 ...
#  $ Outcome                 : Factor w/ 2 levels "Positive","Negative": 2 1 2 1 2 1 2 1 2 2 ...

# %%
set.seed(1234)
# set the 10 fold crossvalidation with AU to pick for us what we call the best model
control <- trainControl(method="cv",number=2, classProbs = TRUE)
metric <- "ROC"

# %%
#Train and Tune the SVM
model <- train(Outcome ~., data = traindf, method = "svmRadial",
                  tuneLength = 8,preProc = c("center","scale"), metric=metric, trControl=control)
# Out:
# Warning message in train.default(x, y, weights = w, ...):
# “The metric "ROC" was not in the result set. Accuracy will be used instead.”

# %%
model
# Out:
# Support Vector Machines with Radial Basis Function Kernel
#
# 692 samples
#   8 predictor
#   2 classes: 'Positive', 'Negative'
#
# Pre-processing: centered (8), scaled (8)
# Resampling: Cross-Validated (2 fold)
# Summary of sample sizes: 346, 346
# Resampling results across tuning parameters:
#
#   C      Accuracy   Kappa
#    0.25  0.7557803  0.4496601
#    0.50  0.7514451  0.4323755
#    1.00  0.7471098  0.4318862
#    2.00  0.7369942  0.4013582
#    4.00  0.7210983  0.3557270
#    8.00  0.7210983  0.3425314
#   16.00  0.7210983  0.3393435
#   32.00  0.7095376  0.2995343
#
# Tuning parameter 'sigma' was held constant at a value of 0.1352951
# Accuracy was used to select the optimal model using the largest value.
# The final values used for the model were sigma = 0.1352951 and C = 0.25.

# %%
plot(model)
# Out:
# plot without title

# %%
predict <- predict(model, newdata = testdf)
confusionMatrix(predict, testdf$Outcome)
# Out:
# Confusion Matrix and Statistics
#
#           Reference
# Prediction Positive Negative
#   Positive       47        9
#   Negative        3       17
#
#                Accuracy : 0.8421
#                  95% CI : (0.7404, 0.9157)
#     No Information Rate : 0.6579
#     P-Value [Acc > NIR] : 0.0002774
#
#                   Kappa : 0.6287
#
#  Mcnemar's Test P-Value : 0.1489147
#
#             Sensitivity : 0.9400
#             Specificity : 0.6538
#          Pos Pred Value : 0.8393
#          Neg Pred Value : 0.8500
#              Prevalence : 0.6579
#          Detection Rate : 0.6184
#    Detection Prevalence : 0.7368
#       Balanced Accuracy : 0.7969
#
#        'Positive' Class : Positive

# %%
set.seed(1234)
grid <- expand.grid(sigma = c(.01, .015, 0.2),
                    C = c(0.75, 0.9, 1, 1.1, 1.25))
 
#Train and Tune the SVM
tune_svm <- train(Outcome ~., data = traindf,
                    method = "svmRadial",
                    preProc = c("center","scale"),
                    metric="ROC",
                    tuneGrid = grid,
                    trControl=control)
# Out:
# Warning message in train.default(x, y, weights = w, ...):
# “The metric "ROC" was not in the result set. Accuracy will be used instead.”

# %%
tune_svm
# Out:
# Support Vector Machines with Radial Basis Function Kernel
#
# 692 samples
#   8 predictor
#   2 classes: 'Positive', 'Negative'
#
# Pre-processing: centered (8), scaled (8)
# Resampling: Cross-Validated (2 fold)
# Summary of sample sizes: 346, 346
# Resampling results across tuning parameters:
#
#   sigma  C     Accuracy   Kappa
#   0.010  0.75  0.7586705  0.4436913
#   0.010  0.90  0.7615607  0.4504055
#   0.010  1.00  0.7644509  0.4592075
#   0.010  1.10  0.7630058  0.4521105
#   0.010  1.25  0.7658960  0.4588502
#   0.015  0.75  0.7586705  0.4469413
#   0.015  0.90  0.7601156  0.4464120
#   0.015  1.00  0.7601156  0.4474730
#   0.015  1.10  0.7630058  0.4464950
#   0.015  1.25  0.7557803  0.4325521
#   0.200  0.75  0.7413295  0.4171433
#   0.200  0.90  0.7500000  0.4305779
#   0.200  1.00  0.7427746  0.4169072
#   0.200  1.10  0.7341040  0.4009477
#   0.200  1.25  0.7369942  0.4004033
#
# Accuracy was used to select the optimal model using the largest value.
# The final values used for the model were sigma = 0.01 and C = 1.25.

# %%
plot(tune_svm)
# Out:
# plot without title

# %%
predict <- predict(tune_svm, newdata = testdf)
confusionMatrix(predict, testdf$Outcome )
# Out:
# Confusion Matrix and Statistics
#
#           Reference
# Prediction Positive Negative
#   Positive       46        8
#   Negative        4       18
#
#                Accuracy : 0.8421
#                  95% CI : (0.7404, 0.9157)
#     No Information Rate : 0.6579
#     P-Value [Acc > NIR] : 0.0002774
#
#                   Kappa : 0.6358
#
#  Mcnemar's Test P-Value : 0.3864762
#
#             Sensitivity : 0.9200
#             Specificity : 0.6923
#          Pos Pred Value : 0.8519
#          Neg Pred Value : 0.8182
#              Prevalence : 0.6579
#          Detection Rate : 0.6053
#    Detection Prevalence : 0.7105
#       Balanced Accuracy : 0.8062
#
#        'Positive' Class : Positive

# %%
dir.create("output")

# %%
save(model, file=file.path("output","model.RData"))
